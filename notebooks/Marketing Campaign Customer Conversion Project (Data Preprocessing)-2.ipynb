# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('Transformed_data.csv')
data
# Out:
#        Unnamed: 0  Age           Job Marital Status Educational Qualification  \
# 0               0   58    management        married                  tertiary
# 1               1   44    technician         single                 secondary
# 2               2   33  entrepreneur        married                 secondary
# 3               3   47   blue-collar        married                       NaN
# 4               4   33       unknown         single                   unknown
# ...           ...  ...           ...            ...                       ...
# 45154       45206   51    technician        married                       NaN
# 45155       45207   71       retired       divorced                   primary
# 45156       45208   72       retired        married                       NaN
# 45157       45209   57   blue-collar        married                 secondary
# 45158       45210   37  entrepreneur        married                 secondary
#
# ...

# %%
data.drop(['Unnamed: 0'],axis=1,inplace = True)

# %%
data
# Out:
#        Age           Job Marital Status Educational Qualification  \
# 0       58    management        married                  tertiary
# 1       44    technician         single                 secondary
# 2       33  entrepreneur        married                 secondary
# 3       47   blue-collar        married                       NaN
# 4       33       unknown         single                   unknown
# ...    ...           ...            ...                       ...
# 45154   51    technician        married                       NaN
# 45155   71       retired       divorced                   primary
# 45156   72       retired        married                       NaN
# 45157   57   blue-collar        married                 secondary
# 45158   37  entrepreneur        married                 secondary
#
#       Contact Communication type  Last Contact Day Of The Month  \
# 0                        unknown                              5
# ...

# %%
married_secondary_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
married_secondary_unknown_yes['Job'].value_counts()
# Out:
# Job
# technician       66
# blue-collar      65
# admin.           49
# services         38
# management       15
# unemployed        9
# retired           7
# self-employed     7
# entrepreneur      7
# housemaid         4
# student           1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('technician')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44640 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_tertiary_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
married_tertiary_unknown_yes['Job'].value_counts()
# Out:
# Job
# management       95
# technician       31
# entrepreneur     13
# self-employed     8
# admin.            7
# retired           2
# unemployed        2
# blue-collar       1
# services          1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44706 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_null_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
married_null_unknown_yes['Job'].value_counts()
# Out:
# Job
# blue-collar      43
# management       43
# technician       26
# admin.           18
# services         12
# entrepreneur      9
# self-employed     8
# housemaid         4
# unemployed        3
# retired           3
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44750 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_unknown_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
married_unknown_unknown_yes['Job'].value_counts()
# Out:
# Job
# management       7
# blue-collar      3
# services         3
# technician       3
# retired          1
# self-employed    1
# admin.           1
# unknown          1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44760 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_primary_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
married_primary_unknown_yes['Job'].value_counts()
# Out:
# Job
# blue-collar     33
# housemaid        7
# services         5
# management       5
# entrepreneur     4
# retired          3
# technician       3
# unknown          2
# unemployed       2
# admin.           2
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44784 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
married_secondary_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
married_secondary_null_yes['Job'].value_counts()
# Out:
# Job
# technician       31
# admin.           29
# blue-collar      25
# services         16
# management        5
# housemaid         3
# self-employed     3
# unemployed        3
# retired           3
# entrepreneur      2
# unknown           1
# student           1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('technician')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44830 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_tertiary_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
married_tertiary_null_yes['Job'].value_counts()
# Out:
# Job
# management       67
# technician       19
# admin.            5
# retired           2
# self-employed     1
# unemployed        1
# services          1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44860 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_null_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
married_null_null_yes['Job'].value_counts()
# Out:
# Job
# management       29
# blue-collar      16
# technician       14
# admin.           11
# housemaid         6
# services          6
# self-employed     4
# unemployed        2
# entrepreneur      1
# retired           1
# unknown           1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44895 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_unknown_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
married_unknown_null_yes['Job'].value_counts()
# Out:
# Job
# blue-collar    4
# housemaid      1
# retired        1
# admin.         1
# management     1
# technician     1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44901 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_primary_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
married_primary_null_yes['Job'].value_counts()
# Out:
# Job
# blue-collar     17
# unemployed       5
# services         4
# management       4
# retired          3
# housemaid        1
# entrepreneur     1
# technician       1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44912 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
married_secondary_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
married_secondary_failure_yes['Job'].value_counts()
# Out:
# Job
# blue-collar      12
# technician       10
# services          9
# admin.            8
# unemployed        6
# management        6
# entrepreneur      3
# self-employed     2
# retired           2
# housemaid         2
# unknown           1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44928 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_tertiary_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
married_tertiary_failure_yes['Job'].value_counts()
# Out:
# Job
# management       23
# technician        8
# admin.            4
# self-employed     2
# entrepreneur      1
# student           1
# unemployed        1
# housemaid         1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44940 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_null_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
married_null_failure_yes['Job'].value_counts()
# Out:
# Job
# admin.           7
# management       5
# technician       4
# blue-collar      4
# unemployed       2
# entrepreneur     2
# housemaid        2
# services         2
# self-employed    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('admin.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44952 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_unknown_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
married_unknown_failure_yes['Job'].value_counts()
# Out:
# Job
# management    1
# student       1
# admin.        1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('student')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44953 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_primary_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
married_primary_failure_yes['Job'].value_counts()
# Out:
# Job
# blue-collar    6
# services       2
# management     1
# housemaid      1
# retired        1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44957 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
married_secondary_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
married_secondary_other_yes['Job'].value_counts()
# Out:
# Job
# blue-collar    6
# technician     5
# admin.         5
# retired        1
# management     1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44962 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_tertiary_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
married_tertiary_other_yes['Job'].value_counts()
# Out:
# Job
# management       11
# technician        3
# entrepreneur      1
# self-employed     1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44973 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_null_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
married_null_other_yes['Job'].value_counts()
# Out:
# Job
# management       6
# blue-collar      5
# admin.           4
# technician       3
# self-employed    2
# services         1
# housemaid        1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44975 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
married_unknown_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
married_unknown_other_yes['Job'].value_counts()
# Out:
# Job
# services      1
# management    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('services')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44976 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
married_primary_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
married_primary_other_yes['Job'].value_counts()
# Out:
# Job
# blue-collar     2
# entrepreneur    1
# technician      1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44976 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
married_primary_success_yes=pd.DataFrame(data.loc[(data['Marital Status']=='married') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='success')])

# %%
married_primary_success_yes['Job'].value_counts()
# Out:
# Job
# management     3
# blue-collar    3
# unknown        1
# retired        1
# services       1
# technician     1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='success'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            44978 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Marital Status'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
divorced_secondary_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
divorced_secondary_unknown_yes['Job'].value_counts()
# Out:
# Job
# admin.           24
# technician       13
# services         11
# management        3
# blue-collar       3
# self-employed     2
# housemaid         2
# unemployed        1
# retired           1
# entrepreneur      1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('admin.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45002 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_tertiary_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
divorced_tertiary_unknown_yes['Job'].value_counts()
# Out:
# Job
# management       27
# technician        7
# entrepreneur      3
# self-employed     3
# unemployed        2
# admin.            2
# retired           1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45018 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_null_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
divorced_null_unknown_yes['Job'].value_counts()
# Out:
# Job
# management       13
# blue-collar       4
# services          4
# technician        4
# admin.            3
# retired           2
# housemaid         2
# self-employed     1
# entrepreneur      1
# unemployed        1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45037 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_unknown_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
divorced_unknown_unknown_yes['Job'].value_counts()
# Out:
# Job
# blue-collar     2
# technician      2
# services        1
# admin.          1
# entrepreneur    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45037 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_primary_unknown_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown')])

# %%
divorced_primary_unknown_yes['Job'].value_counts()
# Out:
# Job
# blue-collar    19
# unemployed      2
# technician      1
# retired         1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='unknown'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45038 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
divorced_secondary_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
divorced_secondary_null_yes['Job'].value_counts()
# Out:
# Job
# technician       8
# unemployed       5
# services         5
# admin.           5
# blue-collar      3
# self-employed    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('technician')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45049 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_tertiary_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
divorced_tertiary_null_yes['Job'].value_counts()
# Out:
# Job
# management       17
# retired           3
# entrepreneur      2
# services          2
# unemployed        1
# technician        1
# self-employed     1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45055 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_null_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
divorced_null_null_yes['Job'].value_counts()
# Out:
# Job
# admin.          5
# management      4
# retired         4
# blue-collar     3
# technician      3
# unemployed      2
# services        1
# entrepreneur    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('admin.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45062 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_unknown_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
divorced_unknown_null_yes['Job'].value_counts()
# Out:
# Job
# unemployed    1
# technician    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('unemployed')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45062 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_primary_null_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull())])

# %%
divorced_primary_null_yes['Job'].value_counts()
# Out:
# Job
# blue-collar      2
# self-employed    1
# retired          1
# housemaid        1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign'].isnull()),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45063 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
divorced_secondary_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
divorced_secondary_failure_yes['Job'].value_counts()
# Out:
# Job
# technician      4
# admin.          3
# services        2
# blue-collar     1
# entrepreneur    1
# retired         1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('technician')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45067 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_tertiary_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
divorced_tertiary_failure_yes['Job'].value_counts()
# Out:
# Job
# management    2
# admin.        1
# technician    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45070 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_null_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
divorced_null_failure_yes['Job'].value_counts()
# Out:
# Job
# management    2
# admin.        1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45070 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_unknown_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
divorced_unknown_failure_yes['Job'].value_counts()
# Out:
# Job
# services    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('services')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45072 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_primary_failure_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure')])

# %%
divorced_primary_failure_yes['Job'].value_counts()
# Out:
# Job
# blue-collar    2
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='failure'),'Job']=data.fillna('blue-collar')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45072 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
divorced_secondary_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='secondary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
divorced_secondary_other_yes['Job'].value_counts()
# Out:
# Job
# admin.        1
# services      1
# retired       1
# technician    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='secondary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('services')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45074 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_tertiary_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='tertiary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
divorced_tertiary_other_yes['Job'].value_counts()
# Out:
# Job
# management       4
# self-employed    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='tertiary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45076 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_null_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification'].isnull()) & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
divorced_null_other_yes['Job'].value_counts()
# Out:
# Job
# admin.        2
# technician    1
# services      1
# management    1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification'].isnull()) & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('admin.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45078 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
divorced_unknown_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='unknown') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
divorced_unknown_other_yes['Job'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
'''data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='unknown') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('services')
 '''

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45078 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', nan, 'unknown', 'primary'], dtype=object)

# %%
divorced_primary_other_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other')])

# %%
divorced_primary_other_yes['Job'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
'''data.loc[(data['Marital Status']=='married') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('blue-collar')'''

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45078 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
divorced_primary_success_yes=pd.DataFrame(data.loc[(data['Marital Status']=='divorced') & (data['Educational Qualification']=='primary') & (data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='success')])

# %%
divorced_primary_success_yes['Job'].value_counts()
# Out:
# Job
# blue-collar    1
# admin.         1
# Name: count, dtype: int64

# %%
data.loc[(data['Marital Status']=='divorced') & 
(data['Educational Qualification']=='primary') & 
(data['Subscription Status']=='yes')
 & (data['Age'].between(31,56)) & (data['Outcome Of Previous Marketing Campaign']=='success'),'Job']=data.fillna('admin.')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45080 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Outcome Of Previous Marketing Campaign'].unique()
# Out:
# array([nan, 'unknown', 'failure', 'other', 'success'], dtype=object)

# %%
data.loc[data['Job'].isnull()]
# Out:
#        Age  Job Marital Status Educational Qualification  \
# 25516   45  NaN       divorced                 secondary
# 26061   40  NaN        married                  tertiary
# 31617   37  NaN        married                 secondary
# 32542   32  NaN       divorced                  tertiary
# 33878   48  NaN        married                 secondary
# ...    ...  ...            ...                       ...
# 45003   42  NaN        married                   unknown
# 45017   52  NaN        married                 secondary
# 45103   44  NaN        married                  tertiary
# 45108   35  NaN        married                 secondary
# 45126   34  NaN        married                 secondary
#
#       Contact Communication type  Last Contact Day Of The Month  \
# 25516                   cellular                             19
# 26061                   cellular                             19
# 31617                  telephone                              6
# ...

# %%
data.loc[(data['Subscription Status']=='yes') & (data['Outcome Of Previous Marketing Campaign']=='success')]['Job'].value_counts()
# Out:
# Job
# management       174
# retired          111
# admin.            80
# technician        76
# student           69
# blue-collar       54
# services          30
# unemployed        25
# self-employed     20
# housemaid          8
# entrepreneur       6
# unknown            3
# Name: count, dtype: int64

# %%
data.loc[(data['Subscription Status']=='yes') & (data['Outcome Of Previous Marketing Campaign']=='success'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45158 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data.loc[data['Job'].isnull()]
# Out:
#        Age  Job Marital Status Educational Qualification  \
# 35469   49  NaN         single                   primary
#
#       Contact Communication type  Last Contact Day Of The Month  \
# 35469                   cellular                              7
#
#       Last Contact Month Of The Year  Contact Duration (Seconds)  \
# 35469                            may                      1516.0
#
#        No Of Contacts Performed During This Campaign  \
# 35469                                              2
#
#       Outcome Of Previous Marketing Campaign Subscription Status Age_Category
# 35469                                  other                 yes        46-50

# %%
data.loc[(data['Subscription Status']=='yes') & (data['Outcome Of Previous Marketing Campaign']=='other'),'Job']=data.fillna('management')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45159 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      33861 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 33862 non-null  object
#  7   Contact Duration (Seconds)                     33908 non-null  float64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data.to_csv('Transformed_data.csv')
