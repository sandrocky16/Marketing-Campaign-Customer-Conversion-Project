# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('Transformed_data.csv')

# %%
data.drop('Unnamed: 0',axis=1,inplace = True)

# %%
data
# Out:
#        Age           Job Marital Status Educational Qualification  \
# 0       58    management        married                  tertiary
# 1       44    technician         single                 secondary
# 2       33  entrepreneur        married                 secondary
# 3       47   blue-collar        married                   primary
# 4       33       unknown         single                   unknown
# ...    ...           ...            ...                       ...
# 45154   51    technician        married                 secondary
# 45155   71       retired       divorced                   primary
# 45156   72       retired        married                 secondary
# 45157   57   blue-collar        married                 secondary
# 45158   37  entrepreneur        married                 secondary
#
#       Contact Communication type  Last Contact Day Of The Month  \
# 0                        unknown                              5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45159 entries, 0 to 45158
# Data columns (total 13 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Age                                            45159 non-null  int64
#  1   Job                                            45159 non-null  object
#  2   Marital Status                                 45159 non-null  object
#  3   Educational Qualification                      45159 non-null  object
#  4   Contact Communication type                     45159 non-null  object
#  5   Last Contact Day Of The Month                  45159 non-null  int64
#  6   Last Contact Month Of The Year                 45159 non-null  object
#  7   Contact Duration (Seconds)                     45159 non-null  int64
#  8   No Of Contacts Performed During This Campaign  45159 non-null  int64
# ...

# %%
data['Educational Qualification'].unique()
# Out:
# array(['tertiary', 'secondary', 'primary', 'unknown'], dtype=object)

# %%
data.loc[(data['Subscription Status']=='no') & (data['Educational Qualification'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Age, Job, Marital Status, Educational Qualification, Contact Communication type, Last Contact Day Of The Month, Last Contact Month Of The Year, Contact Duration (Seconds), No Of Contacts Performed During This Campaign, Outcome Of Previous Marketing Campaign, Subscription Status, Age_Category, Group]
# Index: []

# %%
data.columns
# Out:
# Index(['Age', 'Job', 'Marital Status', 'Educational Qualification',
#        'Contact Communication type', 'Last Contact Day Of The Month',
#        'Last Contact Month Of The Year', 'Contact Duration (Seconds)',
#        'No Of Contacts Performed During This Campaign',
#        'Outcome Of Previous Marketing Campaign', 'Subscription Status',
#        'Age_Category', 'Group'],
#       dtype='object')

# %%
new_data=data[['Job','Marital Status','Educational Qualification','Subscription Status','Outcome Of Previous Marketing Campaign']]
new_data=new_data.loc[new_data['Educational Qualification'].notnull()]
new_data['Group']=1

# %%
new_data
# Out:
#                 Job Marital Status Educational Qualification  \
# 0        management        married                  tertiary
# 1        technician         single                 secondary
# 2      entrepreneur        married                 secondary
# 3       blue-collar        married                   primary
# 4           unknown         single                   unknown
# ...             ...            ...                       ...
# 45154    technician        married                 secondary
# 45155       retired       divorced                   primary
# 45156       retired        married                 secondary
# 45157   blue-collar        married                 secondary
# 45158  entrepreneur        married                 secondary
#
#       Subscription Status Outcome Of Previous Marketing Campaign  Group
# 0                      no                                unknown      1
# 1                      no                                unknown      1
# ...

# %%
n1=pd.DataFrame(new_data.groupby(['Job','Marital Status','Subscription Status','Outcome Of Previous Marketing Campaign','Educational Qualification']).count())
n1.reset_index(inplace=True)
n1
# Out:
#          Job Marital Status Subscription Status  \
# 0     admin.       divorced                  no
# 1     admin.       divorced                  no
# 2     admin.       divorced                  no
# 3     admin.       divorced                  no
# 4     admin.       divorced                  no
# ..       ...            ...                 ...
# 717  unknown         single                 yes
# 718  unknown         single                 yes
# 719  unknown         single                 yes
# 720  unknown         single                 yes
# 721  unknown         single                 yes
#
#     Outcome Of Previous Marketing Campaign Educational Qualification  Group
# 0                                  failure                   primary      1
# 1                                  failure                 secondary     39
# 2                                  failure                  tertiary      4
# 3                                  failure                   unknown      1
# ...

# %%
n1['Job'].unique()
# Out:
# array(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'], dtype=object)

# %%
n1['Marital Status'].unique()
# Out:
# array(['divorced', 'married', 'single'], dtype=object)

# %% [markdown]
# # Code For Filling NA Of Educational Qualification

# %%
'''
n2=n1.loc[(n1['Job']=='unknown') & (n1['Subscription Status']=='yes')]
Marital_Status=n2.loc[n2['Marital Status']=='divorced']
Marital_Status
'''
# Out:
# "\nn2=n1.loc[(n1['Job']=='unknown') & (n1['Subscription Status']=='yes')]\nMarital_Status=n2.loc[n2['Marital Status']=='divorced']\nMarital_Status\n"

# %%
'''
data.loc[(data['Job']=='unknown')  
#& (data['Marital Status']=='divorced') 
#& (data['Subscription Status']=='no') 
#& (data['Outcome Of Previous Marketing Campaign'].isin(['unknown']))
#& (data['Outcome Of Previous Marketing Campaign'].isnull())
,'Educational Qualification']=data.fillna('secondary')
'''
# Out:
# "\ndata.loc[(data['Job']=='unknown')  \n#& (data['Marital Status']=='divorced') \n#& (data['Subscription Status']=='no') \n#& (data['Outcome Of Previous Marketing Campaign'].isin(['unknown']))\n#& (data['Outcome Of Previous Marketing Campaign'].isnull())\n,'Educational Qualification']=data.fillna('secondary')\n"

# %%
'''
data.loc[(data['Job']=='unknown')  
& (data['Educational Qualification'].isnull())]
'''
# Out:
# "\ndata.loc[(data['Job']=='unknown')  \n& (data['Educational Qualification'].isnull())]\n"

# %%
'''
data.loc[(data['Job']=='unknown')  
#& (data['Educational Qualification'].isnull())]
& (data['Marital Status']=='single')
& (data['Subscription Status']=='yes') & (data['Outcome Of Previous Marketing Campaign'].isnull())]['Educational Qualification'].value_counts()
#& (data['Outcome Of Previous Marketing Campaign']=='other')]['Educational Qualification'].value_counts()
#]['Educational Qualification'].value_counts()
'''
# Out:
# "\ndata.loc[(data['Job']=='unknown')  \n#& (data['Educational Qualification'].isnull())]\n& (data['Marital Status']=='single')\n& (data['Subscription Status']=='yes') & (data['Outcome Of Previous Marketing Campaign'].isnull())]['Educational Qualification'].value_counts()\n#& (data['Outcome Of Previous Marketing Campaign']=='other')]['Educational Qualification'].value_counts()\n#]['Educational Qualification'].value_counts()\n"

# %%
'''
data.loc[(data['Job']=='housemaid')  
& (data['Educational Qualification'].isnull())
& (data['Subscription Status']=='no')]

'''
# Out:
# "\ndata.loc[(data['Job']=='housemaid')  \n& (data['Educational Qualification'].isnull())\n& (data['Subscription Status']=='no')]\n\n"

# %% [markdown]
# # Code For Filling NA For Outcome OF Previous Marketing Campaign

# %%
data
# Out:
#        Age           Job Marital Status Educational Qualification  \
# 0       58    management        married                  tertiary
# 1       44    technician         single                 secondary
# 2       33  entrepreneur        married                 secondary
# 3       47   blue-collar        married                   primary
# 4       33       unknown         single                   unknown
# ...    ...           ...            ...                       ...
# 45154   51    technician        married                 secondary
# 45155   71       retired       divorced                   primary
# 45156   72       retired        married                 secondary
# 45157   57   blue-collar        married                 secondary
# 45158   37  entrepreneur        married                 secondary
#
#       Contact Communication type  Last Contact Day Of The Month  \
# 0                        unknown                              5
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Job', 'Marital Status', 'Educational Qualification',
#        'Contact Communication type', 'Last Contact Day Of The Month',
#        'Last Contact Month Of The Year', 'Contact Duration (Seconds)',
#        'No Of Contacts Performed During This Campaign',
#        'Outcome Of Previous Marketing Campaign', 'Subscription Status',
#        'Age_Category', 'Group'],
#       dtype='object')

# %%
data['Group'] = 1

# %%
n3=pd.DataFrame(data.groupby(['Job','Marital Status','Contact Communication type','Subscription Status','Outcome Of Previous Marketing Campaign'])['Group'].count())

# %%
n3.reset_index(inplace = True)

# %%
n3
# Out:
#          Job Marital Status Contact Communication type Subscription Status  \
# 0     admin.       divorced                   cellular                  no
# 1     admin.       divorced                   cellular                  no
# 2     admin.       divorced                   cellular                  no
# 3     admin.       divorced                   cellular                  no
# 4     admin.       divorced                   cellular                 yes
# ..       ...            ...                        ...                 ...
# 520  unknown         single                   cellular                 yes
# 521  unknown         single                   cellular                 yes
# 522  unknown         single                  telephone                  no
# 523  unknown         single                  telephone                 yes
# 524  unknown         single                    unknown                  no
#
#     Outcome Of Previous Marketing Campaign  Group
# ...

# %%
n3['Job'].unique()
# Out:
# array(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'], dtype=object)

# %%
n3['Marital Status'].unique()
# Out:
# array(['divorced', 'married', 'single'], dtype=object)

# %%
n3['Contact Communication type'].unique()
# Out:
# array(['cellular', 'telephone', 'unknown'], dtype=object)

# %%
n3['Subscription Status'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
'''
Job=n3.loc[(n3['Job']=='entrepreneur') & (n3['Marital Status']=='divorced')]
Marital_Status = Job.loc[(Job['Contact Communication type']=='unknown') & (Job['Subscription Status']=='yes')]
Marital_Status
'''
# Out:
# "\nJob=n3.loc[(n3['Job']=='entrepreneur') & (n3['Marital Status']=='divorced')]\nMarital_Status = Job.loc[(Job['Contact Communication type']=='unknown') & (Job['Subscription Status']=='yes')]\nMarital_Status\n"

# %%
'''
data.loc[
(data['Job']=='entrepreneur')
&(data['Marital Status']=='single')
&(data['Contact Communication type']=='unknown')
&(data['Subscription Status']=='no')
,'Outcome Of Previous Marketing Campaign'
]=data.fillna('unknown')
'''
# Out:
# "\ndata.loc[\n(data['Job']=='entrepreneur')\n&(data['Marital Status']=='single')\n&(data['Contact Communication type']=='unknown')\n&(data['Subscription Status']=='no')\n,'Outcome Of Previous Marketing Campaign'\n]=data.fillna('unknown')\n"

# %%
'''
new=pd.DataFrame(
data.loc[
#(data['Contact Communication type']=='cellular') 
 (data['Outcome Of Previous Marketing Campaign'].isnull()) 
& (data['Job']=='entrepreneur')])

new
'''
# Out:
# "\nnew=pd.DataFrame(\ndata.loc[\n#(data['Contact Communication type']=='cellular') \n (data['Outcome Of Previous Marketing Campaign'].isnull()) \n& (data['Job']=='entrepreneur')])\n\nnew\n"

# %% [markdown]
# # Code For Filling NA For Contact Duration (Seconds)

# %%
data
# Out:
#        Age           Job Marital Status Educational Qualification  \
# 0       58    management        married                  tertiary
# 1       44    technician         single                 secondary
# 2       33  entrepreneur        married                 secondary
# 3       47   blue-collar        married                   primary
# 4       33       unknown         single                   unknown
# ...    ...           ...            ...                       ...
# 45154   51    technician        married                 secondary
# 45155   71       retired       divorced                   primary
# 45156   72       retired        married                 secondary
# 45157   57   blue-collar        married                 secondary
# 45158   37  entrepreneur        married                 secondary
#
#       Contact Communication type  Last Contact Day Of The Month  \
# 0                        unknown                              5
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Job', 'Marital Status', 'Educational Qualification',
#        'Contact Communication type', 'Last Contact Day Of The Month',
#        'Last Contact Month Of The Year', 'Contact Duration (Seconds)',
#        'No Of Contacts Performed During This Campaign',
#        'Outcome Of Previous Marketing Campaign', 'Subscription Status',
#        'Age_Category', 'Group'],
#       dtype='object')

# %%
n4=data[['Job', 'Marital Status','Contact Communication type', 'Subscription Status','Contact Duration (Seconds)']]

# %%
n4=n4.loc[n4['Contact Duration (Seconds)'].notnull()]
n4
# Out:
#                 Job Marital Status Contact Communication type  \
# 0        management        married                    unknown
# 1        technician         single                    unknown
# 2      entrepreneur        married                    unknown
# 3       blue-collar        married                    unknown
# 4           unknown         single                    unknown
# ...             ...            ...                        ...
# 45154    technician        married                   cellular
# 45155       retired       divorced                   cellular
# 45156       retired        married                   cellular
# 45157   blue-collar        married                  telephone
# 45158  entrepreneur        married                   cellular
#
#       Subscription Status  Contact Duration (Seconds)
# 0                      no                         261
# 1                      no                         151
# 2                      no                          76
# ...

# %%
contact=pd.DataFrame(n4.groupby(['Job', 'Marital Status','Contact Communication type', 'Subscription Status'])['Contact Duration (Seconds)'].median())

contact.reset_index(inplace = True)

contact
# Out:
#          Job Marital Status Contact Communication type Subscription Status  \
# 0     admin.       divorced                   cellular                  no
# 1     admin.       divorced                   cellular                 yes
# 2     admin.       divorced                  telephone                  no
# 3     admin.       divorced                  telephone                 yes
# 4     admin.       divorced                    unknown                  no
# ..       ...            ...                        ...                 ...
# 201  unknown         single                   cellular                  no
# 202  unknown         single                   cellular                 yes
# 203  unknown         single                  telephone                  no
# 204  unknown         single                  telephone                 yes
# 205  unknown         single                    unknown                  no
#
#      Contact Duration (Seconds)
# 0                         155.0
# ...

# %%
contact['Job'].unique()
# Out:
# array(['admin.', 'blue-collar', 'entrepreneur', 'housemaid', 'management',
#        'retired', 'self-employed', 'services', 'student', 'technician',
#        'unemployed', 'unknown'], dtype=object)

# %%
contact['Marital Status'].unique()
# Out:
# array(['divorced', 'married', 'single'], dtype=object)

# %%
contact['Contact Communication type'].unique()
# Out:
# array(['cellular', 'telephone', 'unknown'], dtype=object)

# %%
'''
Job=contact.loc[(contact['Job'].isin(['entrepreneur'])) & (contact['Marital Status']=='single')
& (contact['Contact Communication type']=='telephone') ]
Job
'''
# Out:
# "\nJob=contact.loc[(contact['Job'].isin(['entrepreneur'])) & (contact['Marital Status']=='single')\n& (contact['Contact Communication type']=='telephone') ]\nJob\n"

# %%
'''
data.loc[(data['Job']=='entrepreneur') 
& (data['Marital Status']=='divorced') 
& (data['Contact Communication type']=='telephone') 
& (data['Subscription Status']=='no')
,'Contact Duration (Seconds)']=data.fillna(301)
'''
# Out:
# "\ndata.loc[(data['Job']=='entrepreneur') \n& (data['Marital Status']=='divorced') \n& (data['Contact Communication type']=='telephone') \n& (data['Subscription Status']=='no')\n,'Contact Duration (Seconds)']=data.fillna(301)\n"

# %%
'''
data.loc[(data['Job']=='entrepreneur') 
& (data['Marital Status']=='single') 
& (data['Contact Communication type']=='telephone') 
& (data['Subscription Status']=='yes')
,'Contact Duration (Seconds)']=data.fillna(114)
'''
# Out:
# "\ndata.loc[(data['Job']=='entrepreneur') \n& (data['Marital Status']=='single') \n& (data['Contact Communication type']=='telephone') \n& (data['Subscription Status']=='yes')\n,'Contact Duration (Seconds)']=data.fillna(114)\n"

# %% [markdown]
# # Code For Filling NA For Last Contact Month Of The Year

# %%
data
# Out:
#        Age           Job Marital Status Educational Qualification  \
# 0       58    management        married                  tertiary
# 1       44    technician         single                 secondary
# 2       33  entrepreneur        married                 secondary
# 3       47   blue-collar        married                   primary
# 4       33       unknown         single                   unknown
# ...    ...           ...            ...                       ...
# 45154   51    technician        married                 secondary
# 45155   71       retired       divorced                   primary
# 45156   72       retired        married                 secondary
# 45157   57   blue-collar        married                 secondary
# 45158   37  entrepreneur        married                 secondary
#
#       Contact Communication type  Last Contact Day Of The Month  \
# 0                        unknown                              5
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Job', 'Marital Status', 'Educational Qualification',
#        'Contact Communication type', 'Last Contact Day Of The Month',
#        'Last Contact Month Of The Year', 'Contact Duration (Seconds)',
#        'No Of Contacts Performed During This Campaign',
#        'Outcome Of Previous Marketing Campaign', 'Subscription Status',
#        'Age_Category', 'Group'],
#       dtype='object')

# %%
'''
new=data[['Last Contact Day Of The Month',
       'Last Contact Month Of The Year',
        'Subscription Status']]
new=pd.DataFrame(new.groupby(['Last Contact Day Of The Month','Subscription Status'])['Last Contact Month Of The Year'].value_counts())
new=new.reset_index()
new
'''
# Out:
# "\nnew=data[['Last Contact Day Of The Month',\n       'Last Contact Month Of The Year',\n        'Subscription Status']]\nnew=pd.DataFrame(new.groupby(['Last Contact Day Of The Month','Subscription Status'])['Last Contact Month Of The Year'].value_counts())\nnew=new.reset_index()\nnew\n"

# %%
'''
new.loc[((new['Last Contact Day Of The Month'])==31)]
'''
# Out:
# "\nnew.loc[((new['Last Contact Day Of The Month'])==31)]\n"

# %%
'''
data.loc[
(data['Last Contact Day Of The Month']==31) 
& (data['Subscription Status']=='no')
,'Last Contact Month Of The Year'
]=data.fillna('jul')
'''
# Out:
# "\ndata.loc[\n(data['Last Contact Day Of The Month']==31) \n& (data['Subscription Status']=='no')\n,'Last Contact Month Of The Year'\n]=data.fillna('jul')\n"

# %%
'''
data.loc[
(data['Last Contact Day Of The Month']==31) 
& (data['Subscription Status']=='yes')
,'Last Contact Month Of The Year'
]=data.fillna('jul')
'''
# Out:
# "\ndata.loc[\n(data['Last Contact Day Of The Month']==31) \n& (data['Subscription Status']=='yes')\n,'Last Contact Month Of The Year'\n]=data.fillna('jul')\n"

# %%
Eda_Data=data.copy()
Model_Data=data.copy()

# %%
'''
data.to_csv('Transformed_data.csv')
'''
# Out:
# "\ndata.to_csv('Transformed_data.csv')\n"

# %%
'''
Eda_Data.to_csv('Eda_Data.csv')
Model_Data.to_csv('Model_Data.csv')
'''
